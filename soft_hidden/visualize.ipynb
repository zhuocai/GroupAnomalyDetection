# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '2019.12.30.main2.py',
#  '2019.12.31.py',
#  'dis_loss.npy',
#  'f_x_h.npy',
#  'gen_data.ipynb',
#  'h.npy',
#  'model.model',
#  'readme.txt',
#  'smoother.npy',
#  'soft_hidden.py',
#  'test.ipynb',
#  'test_x.npy',
#  'train_x.npy',
#  'visualize.ipynb',
#  'x_anomaly_11.npy',
#  'x_normal_11.npy']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
h = np.load('h.npy')

# %%
plt.figure(figsize=(20,10*h.shape[1]))
for i in range(10):
    plt.subplot(10,1,i+1)
    plt.plot(h[:,i])
