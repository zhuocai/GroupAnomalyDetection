# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '2019.12.30.main2.py',
#  '2019.12.31.py',
#  'dis_loss.npy',
#  'f_x_h.npy',
#  'gen_data.ipynb',
#  'h.npy',
#  'model.model',
#  'readme.txt',
#  'smoother.npy',
#  'soft_hidden.py',
#  'test.ipynb',
#  'test_x.npy',
#  'train_x.npy',
#  'Untitled.ipynb',
#  'visualize.ipynb',
#  'x_anomaly_11.npy',
#  'x_normal_11.npy']

# %%
f_x_h = np.load('f_x_h.npy')

# %%
f_x_h.shape
# Out:
# (10000, 1)

# %%
h = np.load('h.npy')

# %%
h.shape
# Out:
# (172801, 10)

# %%
anomaly_np = np.load('../../data/wadi/anomaly_valid.npy')

# %%
anomaly_np.shape
# Out:
# (172801, 96)

# %%
plt.figure(figsize=(14, 7*10))
for i in range(10):
    plt.subplot(10, 1, i+1)
    plt.plot(h[:,i])
